# %% [markdown]
# <a href="https://colab.research.google.com/github/lordChipotle/theTeller/blob/main/theTeller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b82e118c-24ec-4519-bc6c-8558005e748d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b82e118c-24ec-4519-bc6c-8558005e748d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-47-21dc3c638f66> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
import pandas as pd

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['coronavirus-tweet-id-2020-07-31-07.csv']))
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        coordinates  ... user_verified
# 0              NaN  ...         False
# 1              NaN  ...         False
# 2              NaN  ...         False
# 3              NaN  ...         False
# 4              NaN  ...         False
# ...            ...  ...           ...
# 154516         NaN  ...         False
# 154517         NaN  ...         False
# 154518         NaN  ...         False
# 154519         NaN  ...         False
# 154520         NaN  ...         False
#
# [154521 rows x 34 columns]

# %%
dfEn = df.loc[df['lang']=="en"]
dfEn
# Out:
#        coordinates  ... user_verified
# 0              NaN  ...         False
# 1              NaN  ...         False
# 2              NaN  ...         False
# 3              NaN  ...         False
# 4              NaN  ...         False
# ...            ...  ...           ...
# 154516         NaN  ...         False
# 154517         NaN  ...         False
# 154518         NaN  ...         False
# 154519         NaN  ...         False
# 154520         NaN  ...         False
#
# [107459 rows x 34 columns]

# %%
dfP = dfEn[dfEn['text'].str.contains("positive" and ("i"or"I"), na=False)]
dfP.head(10)['text']
# Out:
# 0                                                                                                                                               RT @kurteichenwald: Today, one American died of Covid every 60 seconds.
# 1                                                             Coronavirus Australia live update: Victoria records 627 new Covid-19 cases, with 21 new cases in NSW and one in Qld – latest news https://t.co/3LNZ2vRm3J
# 2                                                                                        RT @DaviSusan: Finally received my (negative) COVID test results from the DC government today...28 days after I took the test.
# 3                To you our Moslem clients &amp; friends @bis_wit @witcart @WitVr. May this year's Eid celebrations bring healing to our world that is going through a pandemic. Enjoy your day https://t.co/ude42qPHqu
# ...

# %%
pd.set_option('max_colwidth', None)
